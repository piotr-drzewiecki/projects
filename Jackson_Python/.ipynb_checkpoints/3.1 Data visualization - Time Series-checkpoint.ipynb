# %% [markdown]
# # 3. Data visualization
# ## 3.1 Time Series

# %%
#loanding pandas and matplotlib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re as re
import datetime as datetime

# %matplotlib inline

# %%
#READ IN CSV HERE>>
df_final_1 = pd.read_csv('C:/Users/juans/Desktop/Python Final Project/df_final.csv')

#Should load in a .csv file with (23123,6) dimentions
df_final_1.head()
# Out:
#        tweet_id  tweet_date tweet_username  \
# 0  4.580307e+17  2014-04-20      Aqilakill
# 1  4.580290e+17  2014-04-20  denizdemirala
# 2  4.580275e+17  2014-04-20  denizdemirala
# 3  4.580226e+17  2014-04-20        dmonic6
# 4  4.580222e+17  2014-04-20   asiyemhrmnli
#
#                                           tweet_text       city  \
# 0  Kartinis Day in Indonesia today. A celebration...  gaziantep
# 1  Bir sabah biri gelip hadi kalk çay demlendi de...  gaziantep
# 2  Uykularımı borç verdim ancak faiz tıkır tıkır ...  gaziantep
# 3                      Bunlar senin cümlelerin değil  gaziantep
# 4  Galiba ben geceyi gündüz gündüzü gece gibi yaş...  gaziantep
#
#                                   tweet_text_frmtted lang
# 0  Kartinis Day in Indonesia today. A celebration...   en
# 1  Bir sabah biri gelip hadi kalk çay demlendi de...   tr
# 2  Uykularımı borç verdim ancak faiz tıkır tıkır ...   tr
# 3                      Bunlar senin cümlelerin değil   tr
# 4  Galiba ben geceyi gündüz gündüzü gece gibi yaş...   tr

# %%
print(df_final_1.groupby(["lang"])["lang"].count().reset_index(name="lang_count").sort_values(by='lang_count', ascending=False))
# Out:
#                   lang  lang_count
# 7                   de       29105
# 9                   en       28946
# 44                  tr       16975
# 18                  hu        4063
# 10                  es        2841
# 19                  id        2169
# 1                   ar        1781
# 31                  pt        1701
# 14                  fr        1651
# 28                  nl        1172
# 43                  tl        1159
# 20                  it        1157
# 33                  ru         940
# 21                  ja         778
# 0                   af         751
# 38                  sv         740
# 42                  th         730
# 36                  so         724
# 29                  no         594
# 32                  ro         541
# 23  lang detect failed         529
# 3                   ca         520
# 11                  et         473
# 6                   da         451
# 30                  pl         418
# 17                  hr         373
# 12                  fa         315
# 13                  fi         245
# 35                  sl         224
# 39                  sw         218
# 5                   cy         213
# 15                  he         153
# 2                   bg         127
# 22                  ko         123
# 47                  vi         102
# 37                  sq         101
# 26                  mk          92
# 8                   el          81
# 4                   cs          77
# 25                  lv          76
# 34                  sk          76
# 24                  lt          56
# 45                  uk          54
# 46                  ur          44
# 48               zh-cn          31
# 49               zh-tw          23
# 27                  ne          18
# 40                  ta           8
# 16                  hi           8
# 41                  te           1

# %%
#total langauge in DataSet
print(df_final_1.lang.unique())
# Out:
# ['en' 'tr' 'tl' 'ro' 'ar' 'id' 'lv' 'de' 'it' 'et' 'da' 'sl'
#  'lang detect failed' 'af' 'pl' 'sk' 'nl' 'no' 'fi' 'hu' 'so' 'cy' 'sq'
#  'sw' 'sv' 'hr' 'pt' 'es' 'ko' 'ca' nan 'fa' 'ur' 'cs' 'vi' 'fr' 'lt' 'ja'
#  'ru' 'bg' 'mk' 'th' 'el' 'uk' 'he' 'zh-cn' 'ta' 'hi' 'ne' 'zh-tw' 'te']

# %%
#by Group
#create table with total daily counts
day_total_count = df_final_1.groupby(["tweet_date"])["lang"].count()\
                                             .reset_index(name="day_total_count")

#create table broken out by day and lang
day_lang_count = df_final_1[df_final_1.lang.isin(['ar','tr','en','de','es','fr'])].groupby(["tweet_date","lang"])["lang"].count()\
                                             .reset_index(name="lang_day_count")\
                                             .sort_values(by=['lang','tweet_date'], ascending=False)

#Join two tables together
day_lang_count_2 = day_lang_count.merge(day_total_count, left_on='tweet_date', right_on='tweet_date')
# creating a column for the daily language share
day_lang_count_2['lang_share_day'] = day_lang_count_2.lang_day_count/day_lang_count_2.day_total_count*100

# %%
line_graph_2_lang = day_lang_count_2.set_index(['tweet_date','lang'], drop = False)
line_graph_2_lang_pivot = line_graph_2_lang.pivot(index='tweet_date', columns='lang', values='lang_share_day')

# %%
line_graph_2_lang_pivot
# Out:
# lang              ar         de         en        es        fr         tr
# tweet_date
# 2014-04-20  2.005452  22.624611  29.186137  3.115265  2.803738  18.496885
# 2014-07-20  2.526942  21.348941  30.416202  4.440728  1.783724  16.406540
# 2014-10-20  1.771845  29.587379  29.223301  2.160194  1.601942  16.577670
# 2015-01-20  1.397554  30.072373  31.594709  1.697030  0.424258  15.373097
# 2015-04-20  2.400519  28.179066  28.265571  1.859862  1.492215  17.776817
# 2015-07-20  0.379327  36.747274  28.212423  2.418208  0.521574  12.897108
# 2015-10-20  1.362142  34.945984  31.094411  1.878816  0.563645  13.245655
# 2016-01-20  0.561272  34.518241  35.032741  1.590271  0.374181   9.681946
# 2016-04-20  0.293501  36.058700  33.626834  0.964361  0.922432   9.769392
# 2016-07-20  0.654818  32.413471  35.827877  1.730589  0.514500   9.869036
# 2016-10-20  0.177830  32.305868  37.581506  2.193242  0.355661   8.476586
# 2017-01-20  0.351370  36.261420  41.391427  2.178496  1.124385   0.983837
# 2017-04-20  0.124922  29.106808  37.663960  0.936914  0.624610  10.930668
# 2017-07-20  0.300842  35.258724  38.206980  2.406739  0.842359   6.137184
# 2017-10-20  0.194301  37.435233  32.966321  1.489637  0.906736   6.606218
# 2018-01-20  0.161551  43.780291  33.602585  1.857835  0.969305   3.715670
# 2018-04-20  0.347826  35.565217  42.260870  2.434783  0.608696   3.130435
# 2018-07-20  0.783290  31.505657  42.819843  3.307224  0.435161   6.179286
# 2018-10-20  0.288739  27.622714  43.503369  2.117421  0.673725   5.197305
# 2019-01-20  0.214362  34.083601  37.942122  1.714898  1.286174   5.680600
# 2019-04-20  1.111552  31.818182  29.118698  4.049226  1.310044  13.497420
# 2019-07-20  2.526003  34.101040  28.640416  3.417533  1.634473   8.655275
# 2019-10-20  1.675095  32.285082  30.072693  3.982301  1.359039  11.757269
# 2020-01-20  1.307815  35.263158  24.816587  3.221691  1.148325  11.307815
# 2020-04-20  2.463680  21.050242  20.644673  2.720944  2.360775  25.487288

# %%
#creating out line graph
fig, ax = plt.subplots(figsize=(15, 8))
plt.plot(line_graph_2_lang_pivot.ar, color='tab:red', linewidth=2, linestyle='-')
plt.plot(line_graph_2_lang_pivot.tr, color='tab:blue', linewidth=2, linestyle=':')
plt.plot(line_graph_2_lang_pivot.en, color='tab:green', linewidth=2, linestyle=(0, (5,2,1,2)))
plt.plot(line_graph_2_lang_pivot.de, color='tab:red', linewidth=2, linestyle='--')
plt.plot(line_graph_2_lang_pivot.fr, color='tab:orange', linewidth=2, linestyle='--' )
plt.plot(line_graph_2_lang_pivot.es, color='cornflowerblue', linewidth=2, linestyle=(0, (5,2,5,2)))

plt.title("Share of tweets by language", fontsize=25)
plt.xlabel("Date of Tweet", fontsize=14)
plt.ylabel("Share of daily tweets (%)", fontsize=14)
plt.legend(["ar","tr",'en',"de","fr","es"], bbox_to_anchor=(1,1), title = 'Languages', fontsize=14)
ax.tick_params(axis="x", labelsize=12, rotation=40)
ax.tick_params(axis="y", labelsize=12)
plt.savefig('language_share_over_time.png')
